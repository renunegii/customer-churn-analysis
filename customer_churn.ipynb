# %%
import os

# Define credentials and repo details
REPOS_DIR = "/content/drive/MyDrive/GitHub"
REPO_NAME = "customer-churn-analysis"
USERNAME = "renunegii"
EMAIL = "officialrenu1@gmail.com"
TOKEN = "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"  # Keep this private!

# Mount Google Drive for persistent storage
from google.colab import drive
drive.mount('/content/drive')

# Create a local GitHub directory if it doesn't exist
os.makedirs(REPOS_DIR, exist_ok=True)
# %cd {REPOS_DIR}

# Clone the repo securely if it hasn't been cloned yet
if not os.path.exists(REPO_NAME):
    # !git clone https://{USERNAME}:{TOKEN}@github.com/{USERNAME}/{REPO_NAME}.git

# Configure Git identity for the runtime session
# %cd {REPO_NAME}
# !git config --global user.name "{USERNAME}"
# !git config --global user.email "{EMAIL}"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/GitHub
# Cloning into 'customer-churn-analysis'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 46 (delta 14), reused 23 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 229.98 KiB | 3.07 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/drive/MyDrive/GitHub/customer-churn-analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/Customer_Data_Cleaned.csv')

# %%
df_backup = df.copy()

# %%
df.head()
# Out:
#   Customer_ID  Gender  Age Married           State  Number_of_Referrals  \
# 0   11098-MAD  Female   30     Yes  Madhya Pradesh                    0
# 1   11114-PUN    Male   51      No          Punjab                    5
# 2   11167-WES  Female   43     Yes     West Bengal                    3
# 3   11179-MAH    Male   35      No     Maharashtra                   10
# 4   11180-TAM    Male   75     Yes      Tamil Nadu                   12
#
#    Tenure_in_Months Value_Deal Phone_Service Multiple_Lines  ...  \
# 0                31     Deal 1           Yes             No  ...
# 1                 9     Deal 5           Yes             No  ...
# 2                28     Deal 1           Yes            Yes  ...
# 3                12    No Deal           Yes             No  ...
# 4                27     Deal 2           Yes             No  ...
#
#     Payment_Method Monthly_Charge Total_Charges Total_Refunds  \
# 0  Bank Withdrawal          95.10       6683.40          0.00
# 1  Bank Withdrawal          49.15        169.05          0.00
# 2  Bank Withdrawal         116.05       8297.50         42.57
# 3      Credit Card          84.40       5969.30          0.00
# 4      Credit Card          72.60       4084.35          0.00
#
#   Total_Extra_Data_Charges Total_Long_Distance_Charges Total_Revenue  \
# 0                        0                      631.72       7315.12
# 1                       10                      122.37        301.42
# 2                      110                     1872.98      10237.91
# 3                        0                      219.39       6188.69
# 4                      140                      332.08       4556.43
#
#   Customer_Status  Churn_Category                   Churn_Reason
# 0          Stayed  Not Applicable                 Not Applicable
# 1         Churned      Competitor  Competitor had better devices
# 2          Stayed  Not Applicable                 Not Applicable
# 3          Stayed  Not Applicable                 Not Applicable
# 4          Stayed  Not Applicable                 Not Applicable
#
# [5 rows x 32 columns]

# %%
df.tail()
# Out:
#      Customer_ID  Gender  Age Married           State  Number_of_Referrals  \
# 6413   99912-WES  Female   60     Yes     West Bengal                   11
# 6414   99942-KER    Male   59     Yes          Kerala                    8
# 6415   99942-TEL  Female   34      No       Telangana                    0
# 6416   99962-AND  Female   63      No  Andhra Pradesh                    7
# 6417   99996-HAR    Male   22     Yes         Haryana                    2
#
#       Tenure_in_Months Value_Deal Phone_Service Multiple_Lines  ...  \
# 6413                26     Deal 4           Yes             No  ...
# 6414                18    No Deal           Yes             No  ...
# 6415                34    No Deal           Yes            Yes  ...
# 6416                 1     Deal 2           Yes            Yes  ...
# 6417                 8     Deal 5           Yes             No  ...
#
#        Payment_Method Monthly_Charge Total_Charges Total_Refunds  \
# 6413  Bank Withdrawal          19.65        244.80           0.0
# 6414  Bank Withdrawal          69.70         69.70           0.0
# 6415      Credit Card          70.90       4677.10           0.0
# 6416      Credit Card          91.60       4627.80           0.0
# 6417      Credit Card          53.55         53.55           0.0
#
#      Total_Extra_Data_Charges Total_Long_Distance_Charges Total_Revenue  \
# 6413                        0                      430.69        675.49
# 6414                        0                       21.52         91.22
# 6415                        0                     1880.02       6557.12
# 6416                       60                      937.04       5624.84
# 6417                        0                       16.06         69.61
#
#      Customer_Status  Churn_Category                  Churn_Reason
# 6413          Stayed  Not Applicable                Not Applicable
# 6414         Churned        Attitude  Attitude of service provider
# 6415          Stayed  Not Applicable                Not Applicable
# 6416          Stayed  Not Applicable                Not Applicable
# 6417          Joined  Not Applicable                Not Applicable
#
# [5 rows x 32 columns]

# %%
df.columns = df.columns.str.strip()
churn_df = df[df['Customer_Status'].isin(['Churned', 'Stayed'])]
churn_df.tail()
# Out:
#      Customer_ID  Gender  Age Married           State  Number_of_Referrals  \
# 6412   99898-MAH  Female   39      No     Maharashtra                    2
# 6413   99912-WES  Female   60     Yes     West Bengal                   11
# 6414   99942-KER    Male   59     Yes          Kerala                    8
# 6415   99942-TEL  Female   34      No       Telangana                    0
# 6416   99962-AND  Female   63      No  Andhra Pradesh                    7
#
#       Tenure_in_Months Value_Deal Phone_Service Multiple_Lines  ...  \
# 6412                14    No Deal           Yes            Yes  ...
# 6413                26     Deal 4           Yes             No  ...
# 6414                18    No Deal           Yes             No  ...
# 6415                34    No Deal           Yes            Yes  ...
# 6416                 1     Deal 2           Yes            Yes  ...
#
#        Payment_Method Monthly_Charge Total_Charges Total_Refunds  \
# 6412  Bank Withdrawal          65.20       3687.85           0.0
# 6413  Bank Withdrawal          19.65        244.80           0.0
# 6414  Bank Withdrawal          69.70         69.70           0.0
# 6415      Credit Card          70.90       4677.10           0.0
# 6416      Credit Card          91.60       4627.80           0.0
#
#      Total_Extra_Data_Charges Total_Long_Distance_Charges Total_Revenue  \
# 6412                        0                       87.78       3775.63
# 6413                        0                      430.69        675.49
# 6414                        0                       21.52         91.22
# 6415                        0                     1880.02       6557.12
# 6416                       60                      937.04       5624.84
#
#      Customer_Status  Churn_Category                  Churn_Reason
# 6412          Stayed  Not Applicable                Not Applicable
# 6413          Stayed  Not Applicable                Not Applicable
# 6414         Churned        Attitude  Attitude of service provider
# 6415          Stayed  Not Applicable                Not Applicable
# 6416          Stayed  Not Applicable                Not Applicable
#
# [5 rows x 32 columns]

# %%
sns.set_style('whitegrid')
fig, axes = plt.subplots(2, 2, figsize=(13, 9))

sns.histplot(churn_df['Age'], bins=20, kde=True, ax=axes[0,0])
axes[0,0].set_title('Age Distribution')

sns.histplot(churn_df['Tenure_in_Months'], bins=20, kde=True, ax=axes[0,1])
axes[0,1].set_title('Tenure (Months) Distribution')

sns.histplot(churn_df['Monthly_Charge'], bins=20, kde=True, ax=axes[1,0])
axes[1,0].set_title('Monthly Charge Distribution')

order = churn_df['Contract'].value_counts().index
sns.countplot(data=churn_df, y='Contract', order=order, ax=axes[1,1])
axes[1,1].set_title('Contract Type Frequency')

plt.tight_layout()
plt.show()
